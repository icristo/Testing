# %% [markdown]
# # 1)Business Problem

# %% [markdown]
# Investors are looking for posible venues investments in Villa Urquiza, Buenos Aires, CABA. This type of investors focus on niche markets, where competition is not a crucial problem.
# They would like to know what type of venue should they invest in and where it should be located.

# %% [markdown]
# # 2)Data Needed

# %% [markdown]
# For solving this problem, i will use the Foursquare API data and geolocalization maps.
# The data required will be the list of all the venues in Villa Urquiza, with its category, location and Rating.
# With further manipulation of this features, i will get the niches venues in Villa Urquiza, with its corresponding Rating Average.
# The conclusion will be the recommendation of a certain venue with its preferable location.

# %% [markdown]
# # 3)CODE

# %%
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     certifi-2019.6.16          |           py36_1         149 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     altair-3.1.0               |           py36_0         724 KB  conda-forge
#     ca-certificates-2019.6.16  |       hecc5488_0         145 KB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.2 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          3.1.0-py36_0      conda-forge
#     branca:          0.3.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.5.15-0                   --> 2019.6.16-hecc5488_0 conda-forge
#     certifi:         2019.6.16-py36_0              --> 2019.6.16-py36_1     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1c-h7b6447c_1             --> 1.1.1c-h516909a_0    conda-forge
#
#
# Downloading and Extracting Packages
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# certifi-2019.6.16    | 149 KB    | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# altair-3.1.0         | 724 KB    | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# openssl-1.1.1c       | 2.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %% [markdown]
# ## Searching venues in Villa Urquiza Buenos Aires

# %%
# Buenos Aires Hurlingham
address = 'Villa Urquiza, Buenos Aires, CABA'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:4: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
# -34.5732414 -58.4914785

# %%
CLIENT_ID = 'PESQIFIZTNDBTMZPSPLZXDCQVGVQT50IE3K1RP3QCQALSDCV' # your Foursquare ID
CLIENT_SECRET = 'ODUYPM1K0ZG1Z0LZTM4GE5IRA0KSMBARQMVDJWAD0HC04UBW' # your Foursquare Secret
VERSION = '20181018'
LIMIT = 300
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: PESQIFIZTNDBTMZPSPLZXDCQVGVQT50IE3K1RP3QCQALSDCV
# CLIENT_SECRET:ODUYPM1K0ZG1Z0LZTM4GE5IRA0KSMBARQMVDJWAD0HC04UBW

# %%
radius = 1000 # Esta en metros
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=PESQIFIZTNDBTMZPSPLZXDCQVGVQT50IE3K1RP3QCQALSDCV&client_secret=ODUYPM1K0ZG1Z0LZTM4GE5IRA0KSMBARQMVDJWAD0HC04UBW&ll=-34.5732414,-58.4914785&v=20181018&radius=1000&limit=300'

# %%
import requests

# %%
results = requests.get(url).json()
'There are {} popular space around Villa Urquiza.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 100 popular space around Villa Urquiza.'

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4e51df2a2271a1bdc400255b',
#   'name': 'Oggi',
#   'location': {'address': 'Bucarelli 2753',
#    'crossStreet': 'Nahuel Huapi',
#    'lat': -34.5727641602655,
#    'lng': -58.491194768062314,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': -34.5727641602655,
#      'lng': -58.491194768062314}],
#    'distance': 59,
#    'postalCode': 'C1431DRG',
#    'cc': 'AR',
#    'city': 'Buenos Aires',
#    'state': 'Buenos Aires C.F.',
#    'country': 'Argentina',
#    'formattedAddress': ['Bucarelli 2753 (Nahuel Huapi)',
#     'C1431DRG Buenos Aires',
#     'Buenos Aires C.F.',
#     'Argentina']},
#   'categories': [{'id': '4bf58dd8d48988d107951735',
#     'name': 'Shoe Store',
#     'pluralName': 'Shoe Stores',
#     'shortName': 'Shoes',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_shoestore_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-0-4e51df2a2271a1bdc400255b-0'}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

# %% [markdown]
# ## All Villa Urquiza Venues

# %%
dataframe_filtered

data_pm = dataframe_filtered[dataframe_filtered["city"] == "Villa Urquiza"]
data_pm
# Out:
#                                      name                 categories  \
# 2                            Las Violetas                     Bakery
# 10                               Al Rayan  Middle Eastern Restaurant
# 11                               Demetrio               Liquor Store
# 12                          Cake & Coffee                Coffee Shop
# 13                       Heladería Italia             Ice Cream Shop
# 17                                Adaggio             Ice Cream Shop
# 19                             Cremolatti             Ice Cream Shop
# 22                          Estilo Misión                 Restaurant
# 25                       Unaghi Sushi Bar           Sushi Restaurant
# 27                        Código Crossfit         Athletics & Sports
# 28                         Laztana Bistro                     Bistro
# 29                              La Quadra                  BBQ Joint
# 30                                 O3 Gym       Gym / Fitness Center
# 34                                 Chungo             Ice Cream Shop
# 36                                La Rana     Argentinian Restaurant
# 41                       Confitería Dobos                     Bakery
# 43                           Itamae Sushi        Japanese Restaurant
# 44                               Taco Box         Mexican Restaurant
# 45                                Frapole             Ice Cream Shop
# 54                              Farmacity                   Pharmacy
# 64                          Espacio Idear                     Lounge
# 65  Estación Gral. Urquiza  [Línea Mitre]              Train Station
# 69                              SportClub                        Gym
# 75                                   Coto              Grocery Store
# 77                               Hausbrot                     Bakery
# 78                                 Freddo             Ice Cream Shop
# 92                     Supermercado Chino              Grocery Store
#
#                           address  cc           city    country  \
# 2               Nahuel Huapi 5300  AR  Villa Urquiza  Argentina
# 10           Blanco Encalada 4902  AR  Villa Urquiza  Argentina
# 11           Av. Triunvirato 4450  AR  Villa Urquiza  Argentina
# 12  Dr. Pedro Ignacio Rivera 4992  AR  Villa Urquiza  Argentina
# 13           Av. Triunvirato 4546  AR  Villa Urquiza  Argentina
# 17                  Olazabal 5598  AR  Villa Urquiza  Argentina
# 19       Avenida Triunvirato 4800  AR  Villa Urquiza  Argentina
# 22                   Mendoza 5100  AR  Villa Urquiza  Argentina
# 25                  Olazábal 4690  AR  Villa Urquiza  Argentina
# 27            Avenida Monroe 4850  AR  Villa Urquiza  Argentina
# 28                   Mendoza 5486  AR  Villa Urquiza  Argentina
# 29                   Mendoza 5502  AR  Villa Urquiza  Argentina
# 30                  Olazabal 5639  AR  Villa Urquiza  Argentina
# 34                  Olazábal 5092  AR  Villa Urquiza  Argentina
# 36        Av. Álvarez Thomas 3425  AR  Villa Urquiza  Argentina
# 41                    Monroe 5180  AR  Villa Urquiza  Argentina
# 43                      Bucarelli  AR  Villa Urquiza  Argentina
# 44                   Barzana 2090  AR  Villa Urquiza  Argentina
# 45                   Mendoza 5496  AR  Villa Urquiza  Argentina
# 54               Triunvirato 4451  AR  Villa Urquiza  Argentina
# 64                   Mendoza 5846  AR  Villa Urquiza  Argentina
# 65                Av. Monroe 5185  AR  Villa Urquiza  Argentina
# 69                    Monroe 4958  AR  Villa Urquiza  Argentina
# 75                    Monroe 5055  AR  Villa Urquiza  Argentina
# 77                  Olazabal 5156  AR  Villa Urquiza  Argentina
# 78              Av. Olazábal 5000  AR  Villa Urquiza  Argentina
# 92                Av. Triunvirato  AR  Villa Urquiza  Argentina
#
#                             crossStreet  distance  \
# 2                        esq. Bucarelli        80
# 10                  esq. Díaz Colodrero       640
# 11                e/ Olazábal y Mendoza       784
# 12          e/ Díaz Colodrero y Pacheco       452
# 13     entre Blanco Encalada y Olazábal       628
# 17                         esq. Ceretti       738
# 19   esq. Avenida Franklin D. Roosevelt       400
# 22                          esq. Ávalos       855
# 25              esq. Av. Álvarez Thomas       905
# 27               Avenida Álvarez Thomas       749
# 28                              Barzana       772
# 29                         esq. Barzana       770
# 30                                  NaN       737
# 34                         esq. Bauness       635
# 36        esq. Dr. Pedro Ignacio Rivera       688
# 41         e/ Av. Triunvirato y Bauness       443
# 43                             Olazabal       637
# 44               e/ Mendoza y Juramento       801
# 45                         esq. Barzana       770
# 54            e/ Av. Olazabal y Mendoza       796
# 64                                  NaN       947
# 65                       esq. Bucarelli       350
# 69          e/ Pacheco y Díaz Colodrero       613
# 75  e/ Díaz Colodrero y Av. Triunvirato       506
# 77               e/ Bauness y Bucarelli       620
# 78                          esq. Ávalos       682
# 92                                Piran       811
#
#                                      formattedAddress  \
# 2   [Nahuel Huapi 5300 (esq. Bucarelli), 1431 Vill...
# 10  [Blanco Encalada 4902 (esq. Díaz Colodrero), C...
# 11  [Av. Triunvirato 4450 (e/ Olazábal y Mendoza),...
# 12  [Dr. Pedro Ignacio Rivera 4992 (e/ Díaz Colodr...
# 13  [Av. Triunvirato 4546 (entre Blanco Encalada y...
# 17  [Olazabal 5598 (esq. Ceretti), C1431CGY Villa ...
# 19  [Avenida Triunvirato 4800 (esq. Avenida Frankl...
# 22  [Mendoza 5100 (esq. Ávalos), C1431CIL Villa Ur...
# 25  [Olazábal 4690 (esq. Av. Álvarez Thomas), 1431...
# 27  [Avenida Monroe 4850 (Avenida Álvarez Thomas),...
# 28  [Mendoza 5486 (Barzana), Villa Urquiza, Buenos...
# 29  [Mendoza 5502 (esq. Barzana), C1431CIT Villa U...
# 30  [Olazabal 5639, 1431 Villa Urquiza, CABA, Arge...
# 34  [Olazábal 5092 (esq. Bauness), C1431CGT Villa ...
# 36  [Av. Álvarez Thomas 3425 (esq. Dr. Pedro Ignac...
# 41  [Monroe 5180 (e/ Av. Triunvirato y Bauness), C...
# 43  [Bucarelli (Olazabal), Villa Urquiza, Buenos A...
# 44  [Barzana 2090 (e/ Mendoza y Juramento), 1431 V...
# 45  [Mendoza 5496 (esq. Barzana), 1431 Villa Urqui...
# 54  [Triunvirato 4451 (e/ Av. Olazabal y Mendoza),...
# 64     [Mendoza 5846, Villa Urquiza, CABA, Argentina]
# 65  [Av. Monroe 5185 (esq. Bucarelli), 1431 Villa ...
# 69  [Monroe 4958 (e/ Pacheco y Díaz Colodrero), 14...
# 75  [Monroe 5055 (e/ Díaz Colodrero y Av. Triunvir...
# 77  [Olazabal 5156 (e/ Bauness y Bucarelli), Villa...
# 78  [Av. Olazábal 5000 (esq. Ávalos), C1431CGS Vil...
# 92  [Av. Triunvirato (Piran), Villa Urquiza, Bueno...
#
#                                        labeledLatLngs        lat        lng  \
# 2   [{'label': 'display', 'lat': -34.5726229433245... -34.572623 -58.491023
# 10  [{'label': 'display', 'lat': -34.5747784614418... -34.574778 -58.484741
# 11  [{'label': 'display', 'lat': -34.5762139701674... -34.576214 -58.483722
# 12  [{'label': 'display', 'lat': -34.5714789058843... -34.571479 -58.487032
# 13  [{'label': 'display', 'lat': -34.5753835866038... -34.575384 -58.485138
# 17  [{'label': 'display', 'lat': -34.5798736809017... -34.579874 -58.491617
# 19  [{'label': 'display', 'lat': -34.5738376376613... -34.573838 -58.487172
# 22  [{'label': 'display', 'lat': -34.5773005233663... -34.577301 -58.483556
# 25  [{'label': 'display', 'lat': -34.5740170900742... -34.574017 -58.481647
# 27  [{'label': 'display', 'lat': -34.5726046379469... -34.572605 -58.483333
# 28  [{'label': 'display', 'lat': -34.57937, 'lng':... -34.579370 -58.487530
# 29  [{'label': 'display', 'lat': -34.5794085439419... -34.579409 -58.487659
# 30  [{'label': 'display', 'lat': -34.5798165718461... -34.579817 -58.492487
# 34  [{'label': 'display', 'lat': -34.5765025036275... -34.576503 -58.485783
# 36  [{'label': 'display', 'lat': -34.5701625807821... -34.570163 -58.484961
# 41  [{'label': 'display', 'lat': -34.574804963366,... -34.574805 -58.487029
# 43  [{'label': 'display', 'lat': -34.5773427306377... -34.577343 -58.486628
# 44  [{'label': 'display', 'lat': -34.5796944237926... -34.579694 -58.487590
# 45  [{'label': 'display', 'lat': -34.5793771946270... -34.579377 -58.487586
# 54  [{'label': 'display', 'lat': -34.5760687832438... -34.576069 -58.483499
# 64  [{'label': 'display', 'lat': -34.5817462168378... -34.581746 -58.490999
# 65  [{'label': 'display', 'lat': -34.5744394483783... -34.574439 -58.487944
# 69  [{'label': 'display', 'lat': -34.5734902175335... -34.573490 -58.484787
# 75  [{'label': 'display', 'lat': -34.573925, 'lng'... -34.573925 -58.486020
# 77  [{'label': 'display', 'lat': -34.5768676705419... -34.576868 -58.486340
# 78  [{'label': 'display', 'lat': -34.5759533719634... -34.575953 -58.484803
# 92  [{'label': 'display', 'lat': -34.5663816550479... -34.566382 -58.494468
#
#                                       neighborhood postalCode  \
# 2                                              NaN       1431
# 10                                             NaN   C1431CDL
# 11                                   Villa Urquiza   C1431FBU
# 12                                   Villa Urquiza   C1431BVJ
# 13                                   Villa Urquiza   C1431FBV
# 17                                             NaN   C1431CGY
# 19                                             NaN   C1431FCN
# 22  Villa Urquiza, Buenos Aires, Buenos Aires F.D.   C1431CIL
# 25                                             NaN       1431
# 27                                             NaN       1431
# 28                                             NaN        NaN
# 29                                             NaN   C1431CIT
# 30                                             NaN       1431
# 34                                             NaN   C1431CGT
# 36  Villa Urquiza, Buenos Aires, Buenos Aires F.D.   C1431FVN
# 41                                   Villa Urquiza   C1431FCR
# 43                                             NaN        NaN
# 44  Villa Urquiza, Buenos Aires, Buenos Aires F.D.       1431
# 45                                             NaN       1431
# 54                                             NaN        NaN
# 64                                             NaN        NaN
# 65                                             NaN       1431
# 69  Villa Urquiza, Buenos Aires, Buenos Aires F.D.       1431
# 75  Villa Urquiza, Buenos Aires, Buenos Aires F.D.   C1431CAO
# 77                                             NaN        NaN
# 78                                             NaN   C1431CGS
# 92                                             NaN        NaN
#
#                 state                        id
# 2   Buenos Aires C.F.  4b783b8cf964a5205dbe2ee3
# 10  Buenos Aires C.F.  4d38eb2476d1a35dc5af028e
# 11  Buenos Aires C.F.  4d8bb3285444a1cd9d13ff73
# 12  Buenos Aires C.F.  4f9c34afe4b07e720d880b94
# 13  Buenos Aires C.F.  4b8729aff964a52014b431e3
# 17  Buenos Aires C.F.  4bc359e2abf49521f79fc393
# 19  Buenos Aires C.F.  542ec57a498ecb8ef93874ff
# 22  Buenos Aires C.F.  4b774731f964a5203a8e2ee3
# 25  Buenos Aires C.F.  4d928498b32737047f888425
# 27  Buenos Aires C.F.  52a4abc4498e1e66f8e64ae1
# 28  Buenos Aires C.F.  5743a712498e393b97d522cc
# 29  Buenos Aires C.F.  4e9a36b029c27d6ad6839f4d
# 30               CABA  5056552ee4b07f9d63e4fd5f
# 34  Buenos Aires C.F.  4d3eb6fafb4c5481d21ee814
# 36  Buenos Aires C.F.  4b64e681f964a5208fd82ae3
# 41  Buenos Aires C.F.  4d24f76c38d0236ad8d1e7b6
# 43  Buenos Aires C.F.  55500954498e6a6680e343a4
# 44  Buenos Aires C.F.  52a3b8a1498e1c34f5d906f4
# 45  Buenos Aires C.F.  4c260f93b012b713edce0893
# 54  Buenos Aires C.F.  4e271da281dc82d74b8a7877
# 64               CABA  4ea57f8c490102dac3e12c99
# 65  Buenos Aires C.F.  4b58de07f964a520bc6f28e3
# 69  Buenos Aires C.F.  4bfd832be529c9284909bb8c
# 75  Buenos Aires C.F.  4b58ebbff964a520127328e3
# 77  Buenos Aires C.F.  5244a83093cd9115170928e1
# 78  Buenos Aires C.F.  559f1a7c498e3287caac71c6
# 92  Buenos Aires C.F.  4db0b8344b22ba776d74d333

# %% [markdown]
# ## Grouped by type of venue.

# %%
group = data_pm.groupby("categories").count()
group1 = group[["name"]]
group1.rename(columns={"name":"Count"},inplace= True)
group1.sort_values("Count",ascending = False,inplace= True)
group1.reset_index(level=0, inplace=True)
group1
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                    categories  Count
# 0              Ice Cream Shop      6
# 1                      Bakery      3
# 2               Grocery Store      2
# 3                Liquor Store      1
# 4            Sushi Restaurant      1
# 5                  Restaurant      1
# 6                    Pharmacy      1
# 7   Middle Eastern Restaurant      1
# 8          Mexican Restaurant      1
# 9                      Lounge      1
# 10     Argentinian Restaurant      1
# 11        Japanese Restaurant      1
# 12         Athletics & Sports      1
# 13       Gym / Fitness Center      1
# 14                        Gym      1
# 15                Coffee Shop      1
# 16                     Bistro      1
# 17                  BBQ Joint      1
# 18              Train Station      1

# %% [markdown]
# #### Base on the information , is not convenient investing in a ice cream shop nor a Restaurant.

# %% [markdown]
# ## Distribution of the venues

# %%
# create map of New York using latitude and longitude values
map_pm = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, category in zip(data_pm['lat'], data_pm['lng'],data_pm["categories"]):
    label = '{}'.format(category)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_pm)  
    
map_pm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Add Rating to the Venue

# %%
# Rating
rating =[]
for venue in data_pm['id'] :
    venue_id = venue
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
    result = requests.get(url).json()
    try:
        rating.append(result['response']['venue']['rating'])
    except:
        rating.append("NaN")


data_pm["Rating"] = rating
data_pm
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                      name                 categories  \
# 2                            Las Violetas                     Bakery
# 10                               Al Rayan  Middle Eastern Restaurant
# 11                               Demetrio               Liquor Store
# 12                          Cake & Coffee                Coffee Shop
# 13                       Heladería Italia             Ice Cream Shop
# 17                                Adaggio             Ice Cream Shop
# 19                             Cremolatti             Ice Cream Shop
# 22                          Estilo Misión                 Restaurant
# 25                       Unaghi Sushi Bar           Sushi Restaurant
# 27                        Código Crossfit         Athletics & Sports
# 28                         Laztana Bistro                     Bistro
# 29                              La Quadra                  BBQ Joint
# 30                                 O3 Gym       Gym / Fitness Center
# 34                                 Chungo             Ice Cream Shop
# 36                                La Rana     Argentinian Restaurant
# 41                       Confitería Dobos                     Bakery
# 43                           Itamae Sushi        Japanese Restaurant
# 44                               Taco Box         Mexican Restaurant
# 45                                Frapole             Ice Cream Shop
# 54                              Farmacity                   Pharmacy
# 64                          Espacio Idear                     Lounge
# 65  Estación Gral. Urquiza  [Línea Mitre]              Train Station
# 69                              SportClub                        Gym
# 75                                   Coto              Grocery Store
# 77                               Hausbrot                     Bakery
# 78                                 Freddo             Ice Cream Shop
# 92                     Supermercado Chino              Grocery Store
#
#                           address  cc           city    country  \
# 2               Nahuel Huapi 5300  AR  Villa Urquiza  Argentina
# 10           Blanco Encalada 4902  AR  Villa Urquiza  Argentina
# 11           Av. Triunvirato 4450  AR  Villa Urquiza  Argentina
# 12  Dr. Pedro Ignacio Rivera 4992  AR  Villa Urquiza  Argentina
# 13           Av. Triunvirato 4546  AR  Villa Urquiza  Argentina
# 17                  Olazabal 5598  AR  Villa Urquiza  Argentina
# 19       Avenida Triunvirato 4800  AR  Villa Urquiza  Argentina
# 22                   Mendoza 5100  AR  Villa Urquiza  Argentina
# 25                  Olazábal 4690  AR  Villa Urquiza  Argentina
# 27            Avenida Monroe 4850  AR  Villa Urquiza  Argentina
# 28                   Mendoza 5486  AR  Villa Urquiza  Argentina
# 29                   Mendoza 5502  AR  Villa Urquiza  Argentina
# 30                  Olazabal 5639  AR  Villa Urquiza  Argentina
# 34                  Olazábal 5092  AR  Villa Urquiza  Argentina
# 36        Av. Álvarez Thomas 3425  AR  Villa Urquiza  Argentina
# 41                    Monroe 5180  AR  Villa Urquiza  Argentina
# 43                      Bucarelli  AR  Villa Urquiza  Argentina
# 44                   Barzana 2090  AR  Villa Urquiza  Argentina
# 45                   Mendoza 5496  AR  Villa Urquiza  Argentina
# 54               Triunvirato 4451  AR  Villa Urquiza  Argentina
# 64                   Mendoza 5846  AR  Villa Urquiza  Argentina
# 65                Av. Monroe 5185  AR  Villa Urquiza  Argentina
# 69                    Monroe 4958  AR  Villa Urquiza  Argentina
# 75                    Monroe 5055  AR  Villa Urquiza  Argentina
# 77                  Olazabal 5156  AR  Villa Urquiza  Argentina
# 78              Av. Olazábal 5000  AR  Villa Urquiza  Argentina
# 92                Av. Triunvirato  AR  Villa Urquiza  Argentina
#
#                             crossStreet  distance  \
# 2                        esq. Bucarelli        80
# 10                  esq. Díaz Colodrero       640
# 11                e/ Olazábal y Mendoza       784
# 12          e/ Díaz Colodrero y Pacheco       452
# 13     entre Blanco Encalada y Olazábal       628
# 17                         esq. Ceretti       738
# 19   esq. Avenida Franklin D. Roosevelt       400
# 22                          esq. Ávalos       855
# 25              esq. Av. Álvarez Thomas       905
# 27               Avenida Álvarez Thomas       749
# 28                              Barzana       772
# 29                         esq. Barzana       770
# 30                                  NaN       737
# 34                         esq. Bauness       635
# 36        esq. Dr. Pedro Ignacio Rivera       688
# 41         e/ Av. Triunvirato y Bauness       443
# 43                             Olazabal       637
# 44               e/ Mendoza y Juramento       801
# 45                         esq. Barzana       770
# 54            e/ Av. Olazabal y Mendoza       796
# 64                                  NaN       947
# 65                       esq. Bucarelli       350
# 69          e/ Pacheco y Díaz Colodrero       613
# 75  e/ Díaz Colodrero y Av. Triunvirato       506
# 77               e/ Bauness y Bucarelli       620
# 78                          esq. Ávalos       682
# 92                                Piran       811
#
#                                      formattedAddress  \
# 2   [Nahuel Huapi 5300 (esq. Bucarelli), 1431 Vill...
# 10  [Blanco Encalada 4902 (esq. Díaz Colodrero), C...
# 11  [Av. Triunvirato 4450 (e/ Olazábal y Mendoza),...
# 12  [Dr. Pedro Ignacio Rivera 4992 (e/ Díaz Colodr...
# 13  [Av. Triunvirato 4546 (entre Blanco Encalada y...
# 17  [Olazabal 5598 (esq. Ceretti), C1431CGY Villa ...
# 19  [Avenida Triunvirato 4800 (esq. Avenida Frankl...
# 22  [Mendoza 5100 (esq. Ávalos), C1431CIL Villa Ur...
# 25  [Olazábal 4690 (esq. Av. Álvarez Thomas), 1431...
# 27  [Avenida Monroe 4850 (Avenida Álvarez Thomas),...
# 28  [Mendoza 5486 (Barzana), Villa Urquiza, Buenos...
# 29  [Mendoza 5502 (esq. Barzana), C1431CIT Villa U...
# 30  [Olazabal 5639, 1431 Villa Urquiza, CABA, Arge...
# 34  [Olazábal 5092 (esq. Bauness), C1431CGT Villa ...
# 36  [Av. Álvarez Thomas 3425 (esq. Dr. Pedro Ignac...
# 41  [Monroe 5180 (e/ Av. Triunvirato y Bauness), C...
# 43  [Bucarelli (Olazabal), Villa Urquiza, Buenos A...
# 44  [Barzana 2090 (e/ Mendoza y Juramento), 1431 V...
# 45  [Mendoza 5496 (esq. Barzana), 1431 Villa Urqui...
# 54  [Triunvirato 4451 (e/ Av. Olazabal y Mendoza),...
# 64     [Mendoza 5846, Villa Urquiza, CABA, Argentina]
# 65  [Av. Monroe 5185 (esq. Bucarelli), 1431 Villa ...
# 69  [Monroe 4958 (e/ Pacheco y Díaz Colodrero), 14...
# 75  [Monroe 5055 (e/ Díaz Colodrero y Av. Triunvir...
# 77  [Olazabal 5156 (e/ Bauness y Bucarelli), Villa...
# 78  [Av. Olazábal 5000 (esq. Ávalos), C1431CGS Vil...
# 92  [Av. Triunvirato (Piran), Villa Urquiza, Bueno...
#
#                                        labeledLatLngs        lat        lng  \
# 2   [{'label': 'display', 'lat': -34.5726229433245... -34.572623 -58.491023
# 10  [{'label': 'display', 'lat': -34.5747784614418... -34.574778 -58.484741
# 11  [{'label': 'display', 'lat': -34.5762139701674... -34.576214 -58.483722
# 12  [{'label': 'display', 'lat': -34.5714789058843... -34.571479 -58.487032
# 13  [{'label': 'display', 'lat': -34.5753835866038... -34.575384 -58.485138
# 17  [{'label': 'display', 'lat': -34.5798736809017... -34.579874 -58.491617
# 19  [{'label': 'display', 'lat': -34.5738376376613... -34.573838 -58.487172
# 22  [{'label': 'display', 'lat': -34.5773005233663... -34.577301 -58.483556
# 25  [{'label': 'display', 'lat': -34.5740170900742... -34.574017 -58.481647
# 27  [{'label': 'display', 'lat': -34.5726046379469... -34.572605 -58.483333
# 28  [{'label': 'display', 'lat': -34.57937, 'lng':... -34.579370 -58.487530
# 29  [{'label': 'display', 'lat': -34.5794085439419... -34.579409 -58.487659
# 30  [{'label': 'display', 'lat': -34.5798165718461... -34.579817 -58.492487
# 34  [{'label': 'display', 'lat': -34.5765025036275... -34.576503 -58.485783
# 36  [{'label': 'display', 'lat': -34.5701625807821... -34.570163 -58.484961
# 41  [{'label': 'display', 'lat': -34.574804963366,... -34.574805 -58.487029
# 43  [{'label': 'display', 'lat': -34.5773427306377... -34.577343 -58.486628
# 44  [{'label': 'display', 'lat': -34.5796944237926... -34.579694 -58.487590
# 45  [{'label': 'display', 'lat': -34.5793771946270... -34.579377 -58.487586
# 54  [{'label': 'display', 'lat': -34.5760687832438... -34.576069 -58.483499
# 64  [{'label': 'display', 'lat': -34.5817462168378... -34.581746 -58.490999
# 65  [{'label': 'display', 'lat': -34.5744394483783... -34.574439 -58.487944
# 69  [{'label': 'display', 'lat': -34.5734902175335... -34.573490 -58.484787
# 75  [{'label': 'display', 'lat': -34.573925, 'lng'... -34.573925 -58.486020
# 77  [{'label': 'display', 'lat': -34.5768676705419... -34.576868 -58.486340
# 78  [{'label': 'display', 'lat': -34.5759533719634... -34.575953 -58.484803
# 92  [{'label': 'display', 'lat': -34.5663816550479... -34.566382 -58.494468
#
#                                       neighborhood postalCode  \
# 2                                              NaN       1431
# 10                                             NaN   C1431CDL
# 11                                   Villa Urquiza   C1431FBU
# 12                                   Villa Urquiza   C1431BVJ
# 13                                   Villa Urquiza   C1431FBV
# 17                                             NaN   C1431CGY
# 19                                             NaN   C1431FCN
# 22  Villa Urquiza, Buenos Aires, Buenos Aires F.D.   C1431CIL
# 25                                             NaN       1431
# 27                                             NaN       1431
# 28                                             NaN        NaN
# 29                                             NaN   C1431CIT
# 30                                             NaN       1431
# 34                                             NaN   C1431CGT
# 36  Villa Urquiza, Buenos Aires, Buenos Aires F.D.   C1431FVN
# 41                                   Villa Urquiza   C1431FCR
# 43                                             NaN        NaN
# 44  Villa Urquiza, Buenos Aires, Buenos Aires F.D.       1431
# 45                                             NaN       1431
# 54                                             NaN        NaN
# 64                                             NaN        NaN
# 65                                             NaN       1431
# 69  Villa Urquiza, Buenos Aires, Buenos Aires F.D.       1431
# 75  Villa Urquiza, Buenos Aires, Buenos Aires F.D.   C1431CAO
# 77                                             NaN        NaN
# 78                                             NaN   C1431CGS
# 92                                             NaN        NaN
#
#                 state                        id Rating
# 2   Buenos Aires C.F.  4b783b8cf964a5205dbe2ee3    7.9
# 10  Buenos Aires C.F.  4d38eb2476d1a35dc5af028e      8
# 11  Buenos Aires C.F.  4d8bb3285444a1cd9d13ff73    8.3
# 12  Buenos Aires C.F.  4f9c34afe4b07e720d880b94    7.4
# 13  Buenos Aires C.F.  4b8729aff964a52014b431e3    7.7
# 17  Buenos Aires C.F.  4bc359e2abf49521f79fc393    7.8
# 19  Buenos Aires C.F.  542ec57a498ecb8ef93874ff    7.1
# 22  Buenos Aires C.F.  4b774731f964a5203a8e2ee3    7.8
# 25  Buenos Aires C.F.  4d928498b32737047f888425    7.8
# 27  Buenos Aires C.F.  52a4abc4498e1e66f8e64ae1    7.5
# 28  Buenos Aires C.F.  5743a712498e393b97d522cc    7.5
# 29  Buenos Aires C.F.  4e9a36b029c27d6ad6839f4d    7.4
# 30               CABA  5056552ee4b07f9d63e4fd5f    7.4
# 34  Buenos Aires C.F.  4d3eb6fafb4c5481d21ee814    7.1
# 36  Buenos Aires C.F.  4b64e681f964a5208fd82ae3    7.1
# 41  Buenos Aires C.F.  4d24f76c38d0236ad8d1e7b6    6.7
# 43  Buenos Aires C.F.  55500954498e6a6680e343a4    6.9
# 44  Buenos Aires C.F.  52a3b8a1498e1c34f5d906f4      7
# 45  Buenos Aires C.F.  4c260f93b012b713edce0893      7
# 54  Buenos Aires C.F.  4e271da281dc82d74b8a7877    6.8
# 64               CABA  4ea57f8c490102dac3e12c99    6.5
# 65  Buenos Aires C.F.  4b58de07f964a520bc6f28e3    5.9
# 69  Buenos Aires C.F.  4bfd832be529c9284909bb8c    5.9
# 75  Buenos Aires C.F.  4b58ebbff964a520127328e3    5.7
# 77  Buenos Aires C.F.  5244a83093cd9115170928e1    5.7
# 78  Buenos Aires C.F.  559f1a7c498e3287caac71c6    5.7
# 92  Buenos Aires C.F.  4db0b8344b22ba776d74d333    NaN

# %% [markdown]
# ## Group by Venue type adding Count and Rating average

# %%
pm_filter = data_pm[data_pm["Rating"] != "NaN"]
pm_filter["Rating"] = pm_filter["Rating"].astype(float)

pmg0 = pm_filter.groupby("categories").count()
pmg1 = pm_filter.groupby("categories").mean()

pmg = pmg0[["name"]]
pmg["Rating"] = pmg1["Rating"]
pmg.rename(columns={"name":"Count"},inplace= True)
pmg.sort_values("Rating",ascending = False,inplace= True)
pmg
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                            Count    Rating
# categories
# Liquor Store                   1  8.300000
# Middle Eastern Restaurant      1  8.000000
# Sushi Restaurant               1  7.800000
# Restaurant                     1  7.800000
# Bistro                         1  7.500000
# Athletics & Sports             1  7.500000
# BBQ Joint                      1  7.400000
# Coffee Shop                    1  7.400000
# Gym / Fitness Center           1  7.400000
# Argentinian Restaurant         1  7.100000
# Ice Cream Shop                 6  7.066667
# Mexican Restaurant             1  7.000000
# Japanese Restaurant            1  6.900000
# Pharmacy                       1  6.800000
# Bakery                         3  6.766667
# Lounge                         1  6.500000
# Gym                            1  5.900000
# Train Station                  1  5.900000
# Grocery Store                  1  5.700000

# %% [markdown]
# ##  a. 1 Conclusion : Based on this information, we need to explore "Grocery Store", "Lounge" , "Pharmacy"

# %%
explo = data_pm[(data_pm["categories"] == "Grocery Store") | (data_pm["categories"] == "Lounge")| (data_pm["categories"] == "Pharmacy")]

explo
# Out:
#                   name     categories           address  cc           city  \
# 54           Farmacity       Pharmacy  Triunvirato 4451  AR  Villa Urquiza
# 64       Espacio Idear         Lounge      Mendoza 5846  AR  Villa Urquiza
# 75                Coto  Grocery Store       Monroe 5055  AR  Villa Urquiza
# 92  Supermercado Chino  Grocery Store   Av. Triunvirato  AR  Villa Urquiza
#
#       country                          crossStreet  distance  \
# 54  Argentina            e/ Av. Olazabal y Mendoza       796
# 64  Argentina                                  NaN       947
# 75  Argentina  e/ Díaz Colodrero y Av. Triunvirato       506
# 92  Argentina                                Piran       811
#
#                                      formattedAddress  \
# 54  [Triunvirato 4451 (e/ Av. Olazabal y Mendoza),...
# 64     [Mendoza 5846, Villa Urquiza, CABA, Argentina]
# 75  [Monroe 5055 (e/ Díaz Colodrero y Av. Triunvir...
# 92  [Av. Triunvirato (Piran), Villa Urquiza, Bueno...
#
#                                        labeledLatLngs        lat        lng  \
# 54  [{'label': 'display', 'lat': -34.5760687832438... -34.576069 -58.483499
# 64  [{'label': 'display', 'lat': -34.5817462168378... -34.581746 -58.490999
# 75  [{'label': 'display', 'lat': -34.573925, 'lng'... -34.573925 -58.486020
# 92  [{'label': 'display', 'lat': -34.5663816550479... -34.566382 -58.494468
#
#                                       neighborhood postalCode  \
# 54                                             NaN        NaN
# 64                                             NaN        NaN
# 75  Villa Urquiza, Buenos Aires, Buenos Aires F.D.   C1431CAO
# 92                                             NaN        NaN
#
#                 state                        id Rating
# 54  Buenos Aires C.F.  4e271da281dc82d74b8a7877    6.8
# 64               CABA  4ea57f8c490102dac3e12c99    6.5
# 75  Buenos Aires C.F.  4b58ebbff964a520127328e3    5.7
# 92  Buenos Aires C.F.  4db0b8344b22ba776d74d333    NaN

# %% [markdown]
# ## Analysis: looking up information online further information online:
# #### Pharmacy: Big company
# #### Grocery Store: Coto is a big company, Supermercado is a small business
# ## b . 2 Conclusion: Opportunity in the Lounge Category. Only 1 competitor, with bad reviews.

# %%
data_lounge = data_pm[data_pm["categories"] == "Lounge"]
data_lounge
# Out:
#              name categories       address  cc           city    country  \
# 64  Espacio Idear     Lounge  Mendoza 5846  AR  Villa Urquiza  Argentina
#
#    crossStreet  distance                                formattedAddress  \
# 64         NaN       947  [Mendoza 5846, Villa Urquiza, CABA, Argentina]
#
#                                        labeledLatLngs        lat        lng  \
# 64  [{'label': 'display', 'lat': -34.5817462168378... -34.581746 -58.490999
#
#    neighborhood postalCode state                        id Rating
# 64          NaN        NaN  CABA  4ea57f8c490102dac3e12c99    6.5

# %% [markdown]
# ### Location of the lounge

# %%
# create map of New York using latitude and longitude values
map_pm1 = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map


for lat, lng, category in zip(data_pm['lat'], data_pm['lng'],data_pm["categories"]):
    label = '{}'.format(category)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_pm1)  
    
for lat, lng, category in zip(data_lounge['lat'], data_lounge['lng'],data_lounge["categories"]):
    label = '{}'.format(category)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=8,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_pm1)     


map_pm1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Venue Information

# %%
venue_id = "4ea57f8c490102dac3e12c99"
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
result = requests.get(url).json()


result
# Out:
# {'meta': {'code': 200, 'requestId': '5d34ee6cdeb49500328efc46'},
#  'response': {'venue': {'id': '4ea57f8c490102dac3e12c99',
#    'name': 'Espacio Idear',
#    'contact': {},
#    'location': {'address': 'Mendoza 5846',
#     'lat': -34.581746216837864,
#     'lng': -58.49099904432911,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': -34.581746216837864,
#       'lng': -58.49099904432911}],
#     'cc': 'AR',
#     'city': 'Villa Urquiza',
#     'state': 'CABA',
#     'country': 'Argentina',
#     'formattedAddress': ['Mendoza 5846',
#      'Villa Urquiza',
#      'CABA',
#      'Argentina']},
#    'canonicalUrl': 'https://foursquare.com/v/espacio-idear/4ea57f8c490102dac3e12c99',
#    'categories': [{'id': '4bf58dd8d48988d121941735',
#      'name': 'Lounge',
#      'pluralName': 'Lounges',
#      'shortName': 'Lounge',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
#    'stats': {'tipCount': 1},
#    'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'},
#    'likes': {'count': 11,
#     'groups': [{'type': 'others', 'count': 11, 'items': []}],
#     'summary': '11 Likes'},
#    'dislike': False,
#    'ok': False,
#    'rating': 6.5,
#    'ratingColor': 'FFC800',
#    'ratingSignals': 17,
#    'allowMenuUrlEdit': True,
#    'beenHere': {'count': 0,
#     'unconfirmedCount': 0,
#     'marked': False,
#     'lastCheckinExpiredAt': 0},
#    'specials': {'count': 0, 'items': []},
#    'photos': {'count': 12,
#     'groups': [{'type': 'checkin',
#       'name': "Friends' check-in photos",
#       'count': 0,
#       'items': []},
#      {'type': 'venue',
#       'name': 'Venue photos',
#       'count': 12,
#       'items': [{'id': '57dfe4bf498ec726be55a946',
#         'createdAt': 1474290879,
#         'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#         'prefix': 'https://fastly.4sqi.net/img/general/',
#         'suffix': '/2718424_1NlZnAPnYSeymLyV2tXofrpZjkMHlGIYtnNkpUHXaj8.jpg',
#         'width': 480,
#         'height': 599,
#         'user': {'id': '2718424',
#          'firstName': 'FOQUUS',
#          'lastName': 'foquus.bb@gmail.com',
#          'gender': 'male',
#          'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#           'suffix': '/2718424-GOWA2Z1T0KVCUJOO.jpg'}},
#         'visibility': 'public'},
#        {'id': '57dfe46c498e923fc6cd611d',
#         'createdAt': 1474290796,
#         'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#         'prefix': 'https://fastly.4sqi.net/img/general/',
#         'suffix': '/2718424_HG1-ND6eNX3MsGHdKPdZ5xW4lWT3j2WX6YzWZQivqOc.jpg',
#         'width': 480,
#         'height': 600,
#         'user': {'id': '2718424',
#          'firstName': 'FOQUUS',
#          'lastName': 'foquus.bb@gmail.com',
#          'gender': 'male',
#          'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#           'suffix': '/2718424-GOWA2Z1T0KVCUJOO.jpg'}},
#         'visibility': 'public'}]}],
#     'summary': '0 photos'},
#    'reasons': {'count': 0, 'items': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'createdAt': 1319468940,
#    'tips': {'count': 1,
#     'groups': [{'type': 'others',
#       'name': 'All tips',
#       'count': 1,
#       'items': [{'id': '517d578ee4b00689fdfe687b',
#         'createdAt': 1367168910,
#         'text': 'Clave del wifi: idear5946',
#         'type': 'user',
#         'canonicalUrl': 'https://foursquare.com/item/517d578ee4b00689fdfe687b',
#         'lang': 'es',
#         'likes': {'count': 0, 'groups': []},
#         'logView': True,
#         'agreeCount': 0,
#         'disagreeCount': 0,
#         'todo': {'count': 0},
#         'user': {'id': '3909198',
#          'firstName': 'Виктор',
#          'gender': 'male',
#          'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#           'suffix': '/IJJMOV4ZL4IGTOFU.jpg'}}}]}]},
#    'shortUrl': 'http://4sq.com/nrPekK',
#    'timeZone': 'America/Argentina/Buenos_Aires',
#    'listed': {'count': 0,
#     'groups': [{'type': 'others',
#       'name': 'Lists from other people',
#       'count': 0,
#       'items': []}]},
#    'pageUpdates': {'count': 0, 'items': []},
#    'inbox': {'count': 0, 'items': []},
#    'attributes': {'groups': [{'type': 'price',
#       'name': 'Price',
#       'summary': '$$$',
#       'count': 1,
#       'items': [{'displayName': 'Price',
#         'displayValue': '$$$',
#         'priceTier': 3}]},
#      {'type': 'outdoorSeating',
#       'name': 'Outdoor Seating',
#       'summary': 'Outdoor Seating',
#       'count': 1,
#       'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'Yes'}]}]},
#    'bestPhoto': {'id': '57dfe4bf498ec726be55a946',
#     'createdAt': 1474290879,
#     'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#     'prefix': 'https://fastly.4sqi.net/img/general/',
#     'suffix': '/2718424_1NlZnAPnYSeymLyV2tXofrpZjkMHlGIYtnNkpUHXaj8.jpg',
#     'width': 480,
#     'height': 599,
#     'visibility': 'public'},
#    'colors': {'highlightColor': {'photoId': '57dfe4bf498ec726be55a946',
#      'value': -1513240},
#     'highlightTextColor': {'photoId': '57dfe4bf498ec726be55a946',
#      'value': -16777216},
#     'algoVersion': 3}}}}

# %% [markdown]
# ### Based on information, is an medium - expensive lounge (3 $ / 5), further onine search
# ### Resulted in a low service quality. Good quality building

# %% [markdown]
# # 4) CONCLUSION:
# ## - Based in the analysis and information available, the most convinient investment in Villa Urquiza is a Lounge.
# ## - There a lack in competition. Focus should rely in a high quaity service, plus convinient instalations.
# ## - Location is not a crucial factor as Lounge dont really need to be in center of the neighbourhood. A center location will be a plus.
# ## - Further analysis may be needed.
